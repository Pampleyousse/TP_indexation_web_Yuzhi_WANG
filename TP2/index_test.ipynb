# %%
import requests
import pandas as pd 
from urllib.parse import urlparse, urljoin, parse_qs
import json
import os
import spacy

# %%
spacy.cli.download("en_core_web_sm")

# %%
data = pd.read_json('input/products.jsonl', lines=True)
urls = data['url'].tolist()
data.head(5)
# Out:
#                                                  url  \
# 0                  https://web-scraping.dev/products
# 1                 https://web-scraping.dev/product/1
# 2                https://web-scraping.dev/product/16
# 3                https://web-scraping.dev/product/10
# 4  https://web-scraping.dev/product/10?variant=bl...
#
#                              title  \
# 0  web-scraping.dev product page 1
# 1           Box of Chocolate Candy
# 2                Red Energy Potion
# 3          Kids' Light-Up Sneakers
# 4          Kids' Light-Up Sneakers
#
#                                          description  \
# 0
# 1  Indulge your sweet tooth with our Box of Choco...
# 2  Elevate your game with our 'Red Potion', an ex...
# 3  Make your child's every step magical with thes...
# 4  Make your child's every step magical with thes...
#
#                                     product_features  \
# 0                                                 {}
# 1  {'material': 'Premium quality chocolate', 'fla...
# 2  {'flavor': 'Intense berry fusion', 'caffeine_c...
# 3  {'material': 'Breathable fabric upper with syn...
# 4  {'material': 'Breathable fabric upper with syn...
#
#                                                links  \
# 0  [https://web-scraping.dev/, https://web-scrapi...
# 1  [https://web-scraping.dev/, https://web-scrapi...
# 2  [https://web-scraping.dev/, https://web-scrapi...
# 3  [https://web-scraping.dev/, https://web-scrapi...
# 4  [https://web-scraping.dev/, https://web-scrapi...
#
#                                      product_reviews
# 0                                                 []
# 1  [{'date': '2022-07-22', 'id': 'chocolate-candy...
# 2  [{'date': '2023-02-10', 'id': 'red-potion-1', ...
# 3  [{'date': '2022-07-01', 'id': 'kids-light-up-s...
# 4  [{'date': '2022-07-01', 'id': 'kids-light-up-s...

# %%
# Extraitre les informations de chaque URL : ID produit (numéro après la tld) et Variante (si présente)
# url exemple : https://web-scraping.dev/product/1?variant=orange-small
def extract_info_url(urls):
    info_list = []
    for url in urls:
        parsed_url = urlparse(url)
        query = parse_qs(parsed_url.query)
        path_parts = parsed_url.path.split('/')
        product_id = path_parts[2] if len(path_parts) > 2 else None
        variant = query.get('variant', [None])[0]
        info_list.append({'url': url, 'product_id': product_id, 'variant': variant})
    return info_list

# %%
extract_info_url(urls)
# Out:
# [{'url': 'https://web-scraping.dev/products',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/1',
#   'product_id': '1',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/16',
#   'product_id': '16',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/10',
#   'product_id': '10',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/10?variant=blue-5',
#   'product_id': '10',
#   'variant': 'blue-5'},
#  {'url': 'https://web-scraping.dev/product/10?variant=blue-6',
#   'product_id': '10',
#   'variant': 'blue-6'},
#  {'url': 'https://web-scraping.dev/product/10?variant=red-5',
#   'product_id': '10',
#   'variant': 'red-5'},
#  {'url': 'https://web-scraping.dev/product/10?variant=red-6',
#   'product_id': '10',
#   'variant': 'red-6'},
#  {'url': 'https://web-scraping.dev/product/11',
#   'product_id': '11',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/11?variant=black40',
#   'product_id': '11',
#   'variant': 'black40'},
#  {'url': 'https://web-scraping.dev/product/11?variant=black41',
#   'product_id': '11',
#   'variant': 'black41'},
#  {'url': 'https://web-scraping.dev/product/11?variant=black42',
#   'product_id': '11',
#   'variant': 'black42'},
#  {'url': 'https://web-scraping.dev/product/11?variant=white40',
#   'product_id': '11',
#   'variant': 'white40'},
#  {'url': 'https://web-scraping.dev/product/11?variant=white41',
#   'product_id': '11',
#   'variant': 'white41'},
#  {'url': 'https://web-scraping.dev/product/11?variant=white42',
#   'product_id': '11',
#   'variant': 'white42'},
#  {'url': 'https://web-scraping.dev/product/12',
#   'product_id': '12',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/12?variant=darkgrey-medium',
#   'product_id': '12',
#   'variant': 'darkgrey-medium'},
#  {'url': 'https://web-scraping.dev/product/12?variant=darkgrey-small',
#   'product_id': '12',
#   'variant': 'darkgrey-small'},
#  {'url': 'https://web-scraping.dev/product/12?variant=grey-medium',
#   'product_id': '12',
#   'variant': 'grey-medium'},
#  {'url': 'https://web-scraping.dev/product/12?variant=grey-small',
#   'product_id': '12',
#   'variant': 'grey-small'},
#  {'url': 'https://web-scraping.dev/product/12?variant=pink-medium',
#   'product_id': '12',
#   'variant': 'pink-medium'},
#  {'url': 'https://web-scraping.dev/product/12?variant=pink-small',
#   'product_id': '12',
#   'variant': 'pink-small'},
#  {'url': 'https://web-scraping.dev/product/12?variant=sand-medium',
#   'product_id': '12',
#   'variant': 'sand-medium'},
#  {'url': 'https://web-scraping.dev/product/12?variant=sand-small',
#   'product_id': '12',
#   'variant': 'sand-small'},
#  {'url': 'https://web-scraping.dev/product/13',
#   'product_id': '13',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/13?variant=cherry-large',
#   'product_id': '13',
#   'variant': 'cherry-large'},
#  {'url': 'https://web-scraping.dev/product/13?variant=cherry-medium',
#   'product_id': '13',
#   'variant': 'cherry-medium'},
#  {'url': 'https://web-scraping.dev/product/13?variant=cherry-small',
#   'product_id': '13',
#   'variant': 'cherry-small'},
#  {'url': 'https://web-scraping.dev/product/13?variant=orange-large',
#   'product_id': '13',
#   'variant': 'orange-large'},
#  {'url': 'https://web-scraping.dev/product/13?variant=orange-medium',
#   'product_id': '13',
#   'variant': 'orange-medium'},
#  {'url': 'https://web-scraping.dev/product/13?variant=orange-small',
#   'product_id': '13',
#   'variant': 'orange-small'},
#  {'url': 'https://web-scraping.dev/product/14',
#   'product_id': '14',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/14?variant=one',
#   'product_id': '14',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/14?variant=six-pack',
#   'product_id': '14',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/15',
#   'product_id': '15',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/15?variant=one',
#   'product_id': '15',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/15?variant=six-pack',
#   'product_id': '15',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/16?variant=one',
#   'product_id': '16',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/16?variant=six-pack',
#   'product_id': '16',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/17',
#   'product_id': '17',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/17?variant=one',
#   'product_id': '17',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/17?variant=six-pack',
#   'product_id': '17',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/18',
#   'product_id': '18',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/18?variant=one',
#   'product_id': '18',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/18?variant=six-pack',
#   'product_id': '18',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/19',
#   'product_id': '19',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/19?variant=6',
#   'product_id': '19',
#   'variant': '6'},
#  {'url': 'https://web-scraping.dev/product/19?variant=7',
#   'product_id': '19',
#   'variant': '7'},
#  {'url': 'https://web-scraping.dev/product/19?variant=8',
#   'product_id': '19',
#   'variant': '8'},
#  {'url': 'https://web-scraping.dev/product/19?variant=9',
#   'product_id': '19',
#   'variant': '9'},
#  {'url': 'https://web-scraping.dev/product/1?variant=cherry-large',
#   'product_id': '1',
#   'variant': 'cherry-large'},
#  {'url': 'https://web-scraping.dev/product/1?variant=cherry-medium',
#   'product_id': '1',
#   'variant': 'cherry-medium'},
#  {'url': 'https://web-scraping.dev/product/1?variant=cherry-small',
#   'product_id': '1',
#   'variant': 'cherry-small'},
#  {'url': 'https://web-scraping.dev/product/1?variant=orange-large',
#   'product_id': '1',
#   'variant': 'orange-large'},
#  {'url': 'https://web-scraping.dev/product/1?variant=orange-medium',
#   'product_id': '1',
#   'variant': 'orange-medium'},
#  {'url': 'https://web-scraping.dev/product/1?variant=orange-small',
#   'product_id': '1',
#   'variant': 'orange-small'},
#  {'url': 'https://web-scraping.dev/product/2',
#   'product_id': '2',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/20',
#   'product_id': '20',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/20?variant=beige-6',
#   'product_id': '20',
#   'variant': 'beige-6'},
#  {'url': 'https://web-scraping.dev/product/20?variant=beige-7',
#   'product_id': '20',
#   'variant': 'beige-7'},
#  {'url': 'https://web-scraping.dev/product/20?variant=beige-8',
#   'product_id': '20',
#   'variant': 'beige-8'},
#  {'url': 'https://web-scraping.dev/product/20?variant=blue-9',
#   'product_id': '20',
#   'variant': 'blue-9'},
#  {'url': 'https://web-scraping.dev/product/21',
#   'product_id': '21',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/21?variant=10',
#   'product_id': '21',
#   'variant': '10'},
#  {'url': 'https://web-scraping.dev/product/21?variant=11',
#   'product_id': '21',
#   'variant': '11'},
#  {'url': 'https://web-scraping.dev/product/21?variant=12',
#   'product_id': '21',
#   'variant': '12'},
#  {'url': 'https://web-scraping.dev/product/21?variant=9',
#   'product_id': '21',
#   'variant': '9'},
#  {'url': 'https://web-scraping.dev/product/22',
#   'product_id': '22',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/22?variant=blue-5',
#   'product_id': '22',
#   'variant': 'blue-5'},
#  {'url': 'https://web-scraping.dev/product/22?variant=blue-6',
#   'product_id': '22',
#   'variant': 'blue-6'},
#  {'url': 'https://web-scraping.dev/product/22?variant=red-5',
#   'product_id': '22',
#   'variant': 'red-5'},
#  {'url': 'https://web-scraping.dev/product/22?variant=red-6',
#   'product_id': '22',
#   'variant': 'red-6'},
#  {'url': 'https://web-scraping.dev/product/23',
#   'product_id': '23',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/23?variant=black40',
#   'product_id': '23',
#   'variant': 'black40'},
#  {'url': 'https://web-scraping.dev/product/23?variant=black41',
#   'product_id': '23',
#   'variant': 'black41'},
#  {'url': 'https://web-scraping.dev/product/23?variant=black42',
#   'product_id': '23',
#   'variant': 'black42'},
#  {'url': 'https://web-scraping.dev/product/23?variant=white40',
#   'product_id': '23',
#   'variant': 'white40'},
#  {'url': 'https://web-scraping.dev/product/23?variant=white41',
#   'product_id': '23',
#   'variant': 'white41'},
#  {'url': 'https://web-scraping.dev/product/23?variant=white42',
#   'product_id': '23',
#   'variant': 'white42'},
#  {'url': 'https://web-scraping.dev/product/24',
#   'product_id': '24',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/24?variant=darkgrey-medium',
#   'product_id': '24',
#   'variant': 'darkgrey-medium'},
#  {'url': 'https://web-scraping.dev/product/24?variant=darkgrey-small',
#   'product_id': '24',
#   'variant': 'darkgrey-small'},
#  {'url': 'https://web-scraping.dev/product/24?variant=grey-medium',
#   'product_id': '24',
#   'variant': 'grey-medium'},
#  {'url': 'https://web-scraping.dev/product/24?variant=grey-small',
#   'product_id': '24',
#   'variant': 'grey-small'},
#  {'url': 'https://web-scraping.dev/product/24?variant=pink-medium',
#   'product_id': '24',
#   'variant': 'pink-medium'},
#  {'url': 'https://web-scraping.dev/product/24?variant=pink-small',
#   'product_id': '24',
#   'variant': 'pink-small'},
#  {'url': 'https://web-scraping.dev/product/24?variant=sand-medium',
#   'product_id': '24',
#   'variant': 'sand-medium'},
#  {'url': 'https://web-scraping.dev/product/24?variant=sand-small',
#   'product_id': '24',
#   'variant': 'sand-small'},
#  {'url': 'https://web-scraping.dev/product/25',
#   'product_id': '25',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/25?variant=cherry-large',
#   'product_id': '25',
#   'variant': 'cherry-large'},
#  {'url': 'https://web-scraping.dev/product/25?variant=cherry-medium',
#   'product_id': '25',
#   'variant': 'cherry-medium'},
#  {'url': 'https://web-scraping.dev/product/25?variant=cherry-small',
#   'product_id': '25',
#   'variant': 'cherry-small'},
#  {'url': 'https://web-scraping.dev/product/25?variant=orange-large',
#   'product_id': '25',
#   'variant': 'orange-large'},
#  {'url': 'https://web-scraping.dev/product/25?variant=orange-medium',
#   'product_id': '25',
#   'variant': 'orange-medium'},
#  {'url': 'https://web-scraping.dev/product/25?variant=orange-small',
#   'product_id': '25',
#   'variant': 'orange-small'},
#  {'url': 'https://web-scraping.dev/product/26',
#   'product_id': '26',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/26?variant=one',
#   'product_id': '26',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/26?variant=six-pack',
#   'product_id': '26',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/27',
#   'product_id': '27',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/27?variant=one',
#   'product_id': '27',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/27?variant=six-pack',
#   'product_id': '27',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/28',
#   'product_id': '28',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/28?variant=one',
#   'product_id': '28',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/28?variant=six-pack',
#   'product_id': '28',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/2?variant=one',
#   'product_id': '2',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/2?variant=six-pack',
#   'product_id': '2',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/3',
#   'product_id': '3',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/3?variant=one',
#   'product_id': '3',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/3?variant=six-pack',
#   'product_id': '3',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/4',
#   'product_id': '4',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/4?variant=one',
#   'product_id': '4',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/4?variant=six-pack',
#   'product_id': '4',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/5',
#   'product_id': '5',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/5?variant=one',
#   'product_id': '5',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/5?variant=six-pack',
#   'product_id': '5',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/6',
#   'product_id': '6',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/6?variant=one',
#   'product_id': '6',
#   'variant': 'one'},
#  {'url': 'https://web-scraping.dev/product/6?variant=six-pack',
#   'product_id': '6',
#   'variant': 'six-pack'},
#  {'url': 'https://web-scraping.dev/product/7',
#   'product_id': '7',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/7?variant=6',
#   'product_id': '7',
#   'variant': '6'},
#  {'url': 'https://web-scraping.dev/product/7?variant=7',
#   'product_id': '7',
#   'variant': '7'},
#  {'url': 'https://web-scraping.dev/product/7?variant=8',
#   'product_id': '7',
#   'variant': '8'},
#  {'url': 'https://web-scraping.dev/product/7?variant=9',
#   'product_id': '7',
#   'variant': '9'},
#  {'url': 'https://web-scraping.dev/product/8',
#   'product_id': '8',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/8?variant=beige-6',
#   'product_id': '8',
#   'variant': 'beige-6'},
#  {'url': 'https://web-scraping.dev/product/8?variant=beige-7',
#   'product_id': '8',
#   'variant': 'beige-7'},
#  {'url': 'https://web-scraping.dev/product/8?variant=beige-8',
#   'product_id': '8',
#   'variant': 'beige-8'},
#  {'url': 'https://web-scraping.dev/product/8?variant=blue-9',
#   'product_id': '8',
#   'variant': 'blue-9'},
#  {'url': 'https://web-scraping.dev/product/9',
#   'product_id': '9',
#   'variant': None},
#  {'url': 'https://web-scraping.dev/product/9?variant=10',
#   'product_id': '9',
#   'variant': '10'},
#  {'url': 'https://web-scraping.dev/product/9?variant=11',
#   'product_id': '9',
#   'variant': '11'},
#  {'url': 'https://web-scraping.dev/product/9?variant=12',
#   'product_id': '9',
#   'variant': '12'},
#  {'url': 'https://web-scraping.dev/product/9?variant=9',
#   'product_id': '9',
#   'variant': '9'},
#  {'url': 'https://web-scraping.dev/products?category=apparel',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=apparel&page=1',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=apparel&page=2',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=apparel&page=3',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=apparel&page=4',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=apparel&page=5',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=consumables',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=consumables&page=1',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=consumables&page=2',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=consumables&page=3',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=consumables&page=4',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=consumables&page=5',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=household',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=household&page=1',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=household&page=2',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=household&page=3',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=household&page=4',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?category=household&page=5',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?page=1',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?page=2',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?page=3',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?page=4',
#   'product_id': None,
#   'variant': None},
#  {'url': 'https://web-scraping.dev/products?page=5',
#   'product_id': None,
#   'variant': None}]

# %%
# Un peu de NLP
def remove_stopwords_punctuation(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    tokens = [token.text.lower() for token in doc if not token.is_stop and not token.is_punct]
    return tokens

# %%
remove_stopwords_punctuation("web-scraping.dev")
# Out:
# ['web-scraping.dev']

# %%
# Trouver la position des mots dans un texte
def word_positions(tokens):
    positions = {}
    for index, token in enumerate(tokens):
        if token not in positions:
            positions[token] = []
        positions[token].append(index)
    return positions

# %%
# Création des index inversés pour les champs 'title' et 'description'
def create_inverted_index(data, field):
    index = {}

    for url, text in zip(data['url'], data[field]):
        tokens = remove_stopwords_punctuation(text)
        positions = word_positions(tokens)
        for token in tokens:
            if token not in index:
                index[token] = {}
            index[token][url] = positions[token]

    return index

# %%
index_title = create_inverted_index(data, 'title')
index_description = create_inverted_index(data, 'description')

# %%
index_description
# Out:
# {'indulge': {'https://web-scraping.dev/product/1': [0],
#   'https://web-scraping.dev/product/13': [0],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [0],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [0],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [0],
#   'https://web-scraping.dev/product/13?variant=orange-large': [0],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [0],
#   'https://web-scraping.dev/product/13?variant=orange-small': [0],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [0],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [0],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [0],
#   'https://web-scraping.dev/product/1?variant=orange-large': [0],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [0],
#   'https://web-scraping.dev/product/1?variant=orange-small': [0],
#   'https://web-scraping.dev/product/25': [0],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [0],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [0],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [0],
#   'https://web-scraping.dev/product/25?variant=orange-large': [0],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [0],
#   'https://web-scraping.dev/product/25?variant=orange-small': [0]},
#  'sweet': {'https://web-scraping.dev/product/1': [1, 21],
#   'https://web-scraping.dev/product/13': [1, 21],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [1, 21],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [1, 21],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [1, 21],
#   'https://web-scraping.dev/product/13?variant=orange-large': [1, 21],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [1, 21],
#   'https://web-scraping.dev/product/13?variant=orange-small': [1, 21],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [1, 21],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [1, 21],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [1, 21],
#   'https://web-scraping.dev/product/1?variant=orange-large': [1, 21],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [1, 21],
#   'https://web-scraping.dev/product/1?variant=orange-small': [1, 21],
#   'https://web-scraping.dev/product/25': [1, 21],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [1, 21],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [1, 21],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [1, 21],
#   'https://web-scraping.dev/product/25?variant=orange-large': [1, 21],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [1, 21],
#   'https://web-scraping.dev/product/25?variant=orange-small': [1, 21]},
#  'tooth': {'https://web-scraping.dev/product/1': [2],
#   'https://web-scraping.dev/product/13': [2],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [2],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [2],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [2],
#   'https://web-scraping.dev/product/13?variant=orange-large': [2],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [2],
#   'https://web-scraping.dev/product/13?variant=orange-small': [2],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [2],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [2],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [2],
#   'https://web-scraping.dev/product/1?variant=orange-large': [2],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [2],
#   'https://web-scraping.dev/product/1?variant=orange-small': [2],
#   'https://web-scraping.dev/product/25': [2],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [2],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [2],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [2],
#   'https://web-scraping.dev/product/25?variant=orange-large': [2],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [2],
#   'https://web-scraping.dev/product/25?variant=orange-small': [2]},
#  'box': {'https://web-scraping.dev/product/1': [3, 6, 28],
#   'https://web-scraping.dev/product/13': [3, 6, 28],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [3, 6, 28],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [3, 6, 28],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [3, 6, 28],
#   'https://web-scraping.dev/product/13?variant=orange-large': [3, 6, 28],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [3, 6, 28],
#   'https://web-scraping.dev/product/13?variant=orange-small': [3, 6, 28],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [3, 6, 28],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [3, 6, 28],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [3, 6, 28],
#   'https://web-scraping.dev/product/1?variant=orange-large': [3, 6, 28],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [3, 6, 28],
#   'https://web-scraping.dev/product/1?variant=orange-small': [3, 6, 28],
#   'https://web-scraping.dev/product/25': [3, 6, 28],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [3, 6, 28],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [3, 6, 28],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [3, 6, 28],
#   'https://web-scraping.dev/product/25?variant=orange-large': [3, 6, 28],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [3, 6, 28],
#   'https://web-scraping.dev/product/25?variant=orange-small': [3, 6, 28]},
#  'chocolate': {'https://web-scraping.dev/product/1': [4, 29],
#   'https://web-scraping.dev/product/13': [4, 29],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [4, 29],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [4, 29],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [4, 29],
#   'https://web-scraping.dev/product/13?variant=orange-large': [4, 29],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [4, 29],
#   'https://web-scraping.dev/product/13?variant=orange-small': [4, 29],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [4, 29],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [4, 29],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [4, 29],
#   'https://web-scraping.dev/product/1?variant=orange-large': [4, 29],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [4, 29],
#   'https://web-scraping.dev/product/1?variant=orange-small': [4, 29],
#   'https://web-scraping.dev/product/25': [4, 29],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [4, 29],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [4, 29],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [4, 29],
#   'https://web-scraping.dev/product/25?variant=orange-large': [4, 29],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [4, 29],
#   'https://web-scraping.dev/product/25?variant=orange-small': [4, 29]},
#  'candy': {'https://web-scraping.dev/product/1': [5, 30],
#   'https://web-scraping.dev/product/13': [5, 30],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [5, 30],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [5, 30],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [5, 30],
#   'https://web-scraping.dev/product/13?variant=orange-large': [5, 30],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [5, 30],
#   'https://web-scraping.dev/product/13?variant=orange-small': [5, 30],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [5, 30],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [5, 30],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [5, 30],
#   'https://web-scraping.dev/product/1?variant=orange-large': [5, 30],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [5, 30],
#   'https://web-scraping.dev/product/1?variant=orange-small': [5, 30],
#   'https://web-scraping.dev/product/25': [5, 30],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [5, 30],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [5, 30],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [5, 30],
#   'https://web-scraping.dev/product/25?variant=orange-large': [5, 30],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [5, 30],
#   'https://web-scraping.dev/product/25?variant=orange-small': [5, 30]},
#  'contains': {'https://web-scraping.dev/product/1': [7],
#   'https://web-scraping.dev/product/13': [7],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [7],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [7],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [7],
#   'https://web-scraping.dev/product/13?variant=orange-large': [7],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [7],
#   'https://web-scraping.dev/product/13?variant=orange-small': [7],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [7],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [7],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [7],
#   'https://web-scraping.dev/product/1?variant=orange-large': [7],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [7],
#   'https://web-scraping.dev/product/1?variant=orange-small': [7],
#   'https://web-scraping.dev/product/25': [7],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [7],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [7],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [7],
#   'https://web-scraping.dev/product/25?variant=orange-large': [7],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [7],
#   'https://web-scraping.dev/product/25?variant=orange-small': [7]},
#  'assortment': {'https://web-scraping.dev/product/1': [8],
#   'https://web-scraping.dev/product/13': [8],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [8],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [8],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [8],
#   'https://web-scraping.dev/product/13?variant=orange-large': [8],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [8],
#   'https://web-scraping.dev/product/13?variant=orange-small': [8],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [8],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [8],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [8],
#   'https://web-scraping.dev/product/1?variant=orange-large': [8],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [8],
#   'https://web-scraping.dev/product/1?variant=orange-small': [8],
#   'https://web-scraping.dev/product/25': [8],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [8],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [8],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [8],
#   'https://web-scraping.dev/product/25?variant=orange-large': [8],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [8],
#   'https://web-scraping.dev/product/25?variant=orange-small': [8]},
#  'rich': {'https://web-scraping.dev/product/1': [9],
#   'https://web-scraping.dev/product/13': [9],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [9],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [9],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [9],
#   'https://web-scraping.dev/product/13?variant=orange-large': [9],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [9],
#   'https://web-scraping.dev/product/13?variant=orange-small': [9],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [9],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [9],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [9],
#   'https://web-scraping.dev/product/1?variant=orange-large': [9],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [9],
#   'https://web-scraping.dev/product/1?variant=orange-small': [9],
#   'https://web-scraping.dev/product/25': [9],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [9],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [9],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [9],
#   'https://web-scraping.dev/product/25?variant=orange-large': [9],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [9],
#   'https://web-scraping.dev/product/25?variant=orange-small': [9]},
#  'flavorful': {'https://web-scraping.dev/product/1': [10],
#   'https://web-scraping.dev/product/13': [10],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [10],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [10],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [10],
#   'https://web-scraping.dev/product/13?variant=orange-large': [10],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [10],
#   'https://web-scraping.dev/product/13?variant=orange-small': [10],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [10],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [10],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [10],
#   'https://web-scraping.dev/product/1?variant=orange-large': [10],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [10],
#   'https://web-scraping.dev/product/1?variant=orange-small': [10],
#   'https://web-scraping.dev/product/25': [10],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [10],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [10],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [10],
#   'https://web-scraping.dev/product/25?variant=orange-large': [10],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [10],
#   'https://web-scraping.dev/product/25?variant=orange-small': [10]},
#  'chocolates': {'https://web-scraping.dev/product/1': [11],
#   'https://web-scraping.dev/product/13': [11],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [11],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [11],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [11],
#   'https://web-scraping.dev/product/13?variant=orange-large': [11],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [11],
#   'https://web-scraping.dev/product/13?variant=orange-small': [11],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [11],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [11],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [11],
#   'https://web-scraping.dev/product/1?variant=orange-large': [11],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [11],
#   'https://web-scraping.dev/product/1?variant=orange-small': [11],
#   'https://web-scraping.dev/product/25': [11],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [11],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [11],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [11],
#   'https://web-scraping.dev/product/25?variant=orange-large': [11],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [11],
#   'https://web-scraping.dev/product/25?variant=orange-small': [11]},
#  'smooth': {'https://web-scraping.dev/product/1': [12],
#   'https://web-scraping.dev/product/13': [12],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [12],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [12],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [12],
#   'https://web-scraping.dev/product/13?variant=orange-large': [12],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [12],
#   'https://web-scraping.dev/product/13?variant=orange-small': [12],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [12],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [12],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [12],
#   'https://web-scraping.dev/product/1?variant=orange-large': [12],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [12],
#   'https://web-scraping.dev/product/1?variant=orange-small': [12],
#   'https://web-scraping.dev/product/25': [12],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [12],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [12],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [12],
#   'https://web-scraping.dev/product/25?variant=orange-large': [12],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [12],
#   'https://web-scraping.dev/product/25?variant=orange-small': [12]},
#  'creamy': {'https://web-scraping.dev/product/1': [13],
#   'https://web-scraping.dev/product/13': [13],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [13],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [13],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [13],
#   'https://web-scraping.dev/product/13?variant=orange-large': [13],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [13],
#   'https://web-scraping.dev/product/13?variant=orange-small': [13],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [13],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [13],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [13],
#   'https://web-scraping.dev/product/1?variant=orange-large': [13],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [13],
#   'https://web-scraping.dev/product/1?variant=orange-small': [13],
#   'https://web-scraping.dev/product/25': [13],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [13],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [13],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [13],
#   'https://web-scraping.dev/product/25?variant=orange-large': [13],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [13],
#   'https://web-scraping.dev/product/25?variant=orange-small': [13]},
#  'filling': {'https://web-scraping.dev/product/1': [14],
#   'https://web-scraping.dev/product/13': [14],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [14],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [14],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [14],
#   'https://web-scraping.dev/product/13?variant=orange-large': [14],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [14],
#   'https://web-scraping.dev/product/13?variant=orange-small': [14],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [14],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [14],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [14],
#   'https://web-scraping.dev/product/1?variant=orange-large': [14],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [14],
#   'https://web-scraping.dev/product/1?variant=orange-small': [14],
#   'https://web-scraping.dev/product/25': [14],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [14],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [14],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [14],
#   'https://web-scraping.dev/product/25?variant=orange-large': [14],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [14],
#   'https://web-scraping.dev/product/25?variant=orange-small': [14]},
#  'choose': {'https://web-scraping.dev/product/1': [15],
#   'https://web-scraping.dev/product/13': [15],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [15],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [15],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [15],
#   'https://web-scraping.dev/product/13?variant=orange-large': [15],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [15],
#   'https://web-scraping.dev/product/13?variant=orange-small': [15],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [15],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [15],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [15],
#   'https://web-scraping.dev/product/1?variant=orange-large': [15],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [15],
#   'https://web-scraping.dev/product/1?variant=orange-small': [15],
#   'https://web-scraping.dev/product/20': [25],
#   'https://web-scraping.dev/product/20?variant=beige-6': [25],
#   'https://web-scraping.dev/product/20?variant=beige-7': [25],
#   'https://web-scraping.dev/product/20?variant=beige-8': [25],
#   'https://web-scraping.dev/product/20?variant=blue-9': [25],
#   'https://web-scraping.dev/product/25': [15],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [15],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [15],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [15],
#   'https://web-scraping.dev/product/25?variant=orange-large': [15],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [15],
#   'https://web-scraping.dev/product/25?variant=orange-small': [15],
#   'https://web-scraping.dev/product/8': [25],
#   'https://web-scraping.dev/product/8?variant=beige-6': [25],
#   'https://web-scraping.dev/product/8?variant=beige-7': [25],
#   'https://web-scraping.dev/product/8?variant=beige-8': [25],
#   'https://web-scraping.dev/product/8?variant=blue-9': [25]},
#  'variety': {'https://web-scraping.dev/product/1': [16],
#   'https://web-scraping.dev/product/12': [28],
#   'https://web-scraping.dev/product/12?variant=darkgrey-medium': [28],
#   'https://web-scraping.dev/product/12?variant=darkgrey-small': [28],
#   'https://web-scraping.dev/product/12?variant=grey-medium': [28],
#   'https://web-scraping.dev/product/12?variant=grey-small': [28],
#   'https://web-scraping.dev/product/12?variant=pink-medium': [28],
#   'https://web-scraping.dev/product/12?variant=pink-small': [28],
#   'https://web-scraping.dev/product/12?variant=sand-medium': [28],
#   'https://web-scraping.dev/product/12?variant=sand-small': [28],
#   'https://web-scraping.dev/product/13': [16],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [16],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [16],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [16],
#   'https://web-scraping.dev/product/13?variant=orange-large': [16],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [16],
#   'https://web-scraping.dev/product/13?variant=orange-small': [16],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [16],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [16],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [16],
#   'https://web-scraping.dev/product/1?variant=orange-large': [16],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [16],
#   'https://web-scraping.dev/product/1?variant=orange-small': [16],
#   'https://web-scraping.dev/product/24': [28],
#   'https://web-scraping.dev/product/24?variant=darkgrey-medium': [28],
#   'https://web-scraping.dev/product/24?variant=darkgrey-small': [28],
#   'https://web-scraping.dev/product/24?variant=grey-medium': [28],
#   'https://web-scraping.dev/product/24?variant=grey-small': [28],
#   'https://web-scraping.dev/product/24?variant=pink-medium': [28],
#   'https://web-scraping.dev/product/24?variant=pink-small': [28],
#   'https://web-scraping.dev/product/24?variant=sand-medium': [28],
#   'https://web-scraping.dev/product/24?variant=sand-small': [28],
#   'https://web-scraping.dev/product/25': [16],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [16],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [16],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [16],
#   'https://web-scraping.dev/product/25?variant=orange-large': [16],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [16],
#   'https://web-scraping.dev/product/25?variant=orange-small': [16]},
#  'flavors': {'https://web-scraping.dev/product/1': [17],
#   'https://web-scraping.dev/product/13': [17],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [17],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [17],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [17],
#   'https://web-scraping.dev/product/13?variant=orange-large': [17],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [17],
#   'https://web-scraping.dev/product/13?variant=orange-small': [17],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [17],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [17],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [17],
#   'https://web-scraping.dev/product/1?variant=orange-large': [17],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [17],
#   'https://web-scraping.dev/product/1?variant=orange-small': [17],
#   'https://web-scraping.dev/product/25': [17],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [17],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [17],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [17],
#   'https://web-scraping.dev/product/25?variant=orange-large': [17],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [17],
#   'https://web-scraping.dev/product/25?variant=orange-small': [17]},
#  'including': {'https://web-scraping.dev/product/1': [18],
#   'https://web-scraping.dev/product/13': [18],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [18],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [18],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [18],
#   'https://web-scraping.dev/product/13?variant=orange-large': [18],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [18],
#   'https://web-scraping.dev/product/13?variant=orange-small': [18],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [18],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [18],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [18],
#   'https://web-scraping.dev/product/1?variant=orange-large': [18],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [18],
#   'https://web-scraping.dev/product/1?variant=orange-small': [18],
#   'https://web-scraping.dev/product/25': [18],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [18],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [18],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [18],
#   'https://web-scraping.dev/product/25?variant=orange-large': [18],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [18],
#   'https://web-scraping.dev/product/25?variant=orange-small': [18]},
#  'zesty': {'https://web-scraping.dev/product/1': [19],
#   'https://web-scraping.dev/product/13': [19],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [19],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [19],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [19],
#   'https://web-scraping.dev/product/13?variant=orange-large': [19],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [19],
#   'https://web-scraping.dev/product/13?variant=orange-small': [19],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [19],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [19],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [19],
#   'https://web-scraping.dev/product/1?variant=orange-large': [19],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [19],
#   'https://web-scraping.dev/product/1?variant=orange-small': [19],
#   'https://web-scraping.dev/product/25': [19],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [19],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [19],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [19],
#   'https://web-scraping.dev/product/25?variant=orange-large': [19],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [19],
#   'https://web-scraping.dev/product/25?variant=orange-small': [19]},
#  'orange': {'https://web-scraping.dev/product/1': [20],
#   'https://web-scraping.dev/product/13': [20],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [20],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [20],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [20],
#   'https://web-scraping.dev/product/13?variant=orange-large': [20],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [20],
#   'https://web-scraping.dev/product/13?variant=orange-small': [20],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [20],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [20],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [20],
#   'https://web-scraping.dev/product/1?variant=orange-large': [20],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [20],
#   'https://web-scraping.dev/product/1?variant=orange-small': [20],
#   'https://web-scraping.dev/product/25': [20],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [20],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [20],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [20],
#   'https://web-scraping.dev/product/25?variant=orange-large': [20],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [20],
#   'https://web-scraping.dev/product/25?variant=orange-small': [20]},
#  'cherry': {'https://web-scraping.dev/product/1': [22],
#   'https://web-scraping.dev/product/13': [22],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [22],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [22],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [22],
#   'https://web-scraping.dev/product/13?variant=orange-large': [22],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [22],
#   'https://web-scraping.dev/product/13?variant=orange-small': [22],
#   'https://web-scraping.dev/product/14': [14],
#   'https://web-scraping.dev/product/14?variant=one': [14],
#   'https://web-scraping.dev/product/14?variant=six-pack': [14],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [22],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [22],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [22],
#   'https://web-scraping.dev/product/1?variant=orange-large': [22],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [22],
#   'https://web-scraping.dev/product/1?variant=orange-small': [22],
#   'https://web-scraping.dev/product/2': [14],
#   'https://web-scraping.dev/product/25': [22],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [22],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [22],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [22],
#   'https://web-scraping.dev/product/25?variant=orange-large': [22],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [22],
#   'https://web-scraping.dev/product/25?variant=orange-small': [22],
#   'https://web-scraping.dev/product/26': [14],
#   'https://web-scraping.dev/product/26?variant=one': [14],
#   'https://web-scraping.dev/product/26?variant=six-pack': [14],
#   'https://web-scraping.dev/product/2?variant=one': [14],
#   'https://web-scraping.dev/product/2?variant=six-pack': [14]},
#  'looking': {'https://web-scraping.dev/product/1': [23],
#   'https://web-scraping.dev/product/13': [23],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [23],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [23],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [23],
#   'https://web-scraping.dev/product/13?variant=orange-large': [23],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [23],
#   'https://web-scraping.dev/product/13?variant=orange-small': [23],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [23],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [23],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [23],
#   'https://web-scraping.dev/product/1?variant=orange-large': [23],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [23],
#   'https://web-scraping.dev/product/1?variant=orange-small': [23],
#   'https://web-scraping.dev/product/25': [23],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [23],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [23],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [23],
#   'https://web-scraping.dev/product/25?variant=orange-large': [23],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [23],
#   'https://web-scraping.dev/product/25?variant=orange-small': [23]},
#  'perfect': {'https://web-scraping.dev/product/1': [24],
#   'https://web-scraping.dev/product/12': [20],
#   'https://web-scraping.dev/product/12?variant=darkgrey-medium': [20],
#   'https://web-scraping.dev/product/12?variant=darkgrey-small': [20],
#   'https://web-scraping.dev/product/12?variant=grey-medium': [20],
#   'https://web-scraping.dev/product/12?variant=grey-small': [20],
#   'https://web-scraping.dev/product/12?variant=pink-medium': [20],
#   'https://web-scraping.dev/product/12?variant=pink-small': [20],
#   'https://web-scraping.dev/product/12?variant=sand-medium': [20],
#   'https://web-scraping.dev/product/12?variant=sand-small': [20],
#   'https://web-scraping.dev/product/13': [24],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [24],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [24],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [24],
#   'https://web-scraping.dev/product/13?variant=orange-large': [24],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [24],
#   'https://web-scraping.dev/product/13?variant=orange-small': [24],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [24],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [24],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [24],
#   'https://web-scraping.dev/product/1?variant=orange-large': [24],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [24],
#   'https://web-scraping.dev/product/1?variant=orange-small': [24],
#   'https://web-scraping.dev/product/20': [18],
#   'https://web-scraping.dev/product/20?variant=beige-6': [18],
#   'https://web-scraping.dev/product/20?variant=beige-7': [18],
#   'https://web-scraping.dev/product/20?variant=beige-8': [18],
#   'https://web-scraping.dev/product/20?variant=blue-9': [18],
#   'https://web-scraping.dev/product/24': [20],
#   'https://web-scraping.dev/product/24?variant=darkgrey-medium': [20],
#   'https://web-scraping.dev/product/24?variant=darkgrey-small': [20],
#   'https://web-scraping.dev/product/24?variant=grey-medium': [20],
#   'https://web-scraping.dev/product/24?variant=grey-small': [20],
#   'https://web-scraping.dev/product/24?variant=pink-medium': [20],
#   'https://web-scraping.dev/product/24?variant=pink-small': [20],
#   'https://web-scraping.dev/product/24?variant=sand-medium': [20],
#   'https://web-scraping.dev/product/24?variant=sand-small': [20],
#   'https://web-scraping.dev/product/25': [24],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [24],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [24],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [24],
#   'https://web-scraping.dev/product/25?variant=orange-large': [24],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [24],
#   'https://web-scraping.dev/product/25?variant=orange-small': [24],
#   'https://web-scraping.dev/product/8': [18],
#   'https://web-scraping.dev/product/8?variant=beige-6': [18],
#   'https://web-scraping.dev/product/8?variant=beige-7': [18],
#   'https://web-scraping.dev/product/8?variant=beige-8': [18],
#   'https://web-scraping.dev/product/8?variant=blue-9': [18]},
#  'gift': {'https://web-scraping.dev/product/1': [25],
#   'https://web-scraping.dev/product/13': [25],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [25],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [25],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [25],
#   'https://web-scraping.dev/product/13?variant=orange-large': [25],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [25],
#   'https://web-scraping.dev/product/13?variant=orange-small': [25],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [25],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [25],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [25],
#   'https://web-scraping.dev/product/1?variant=orange-large': [25],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [25],
#   'https://web-scraping.dev/product/1?variant=orange-small': [25],
#   'https://web-scraping.dev/product/25': [25],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [25],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [25],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [25],
#   'https://web-scraping.dev/product/25?variant=orange-large': [25],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [25],
#   'https://web-scraping.dev/product/25?variant=orange-small': [25]},
#  'want': {'https://web-scraping.dev/product/1': [26],
#   'https://web-scraping.dev/product/13': [26],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [26],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [26],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [26],
#   'https://web-scraping.dev/product/13?variant=orange-large': [26],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [26],
#   'https://web-scraping.dev/product/13?variant=orange-small': [26],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [26],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [26],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [26],
#   'https://web-scraping.dev/product/1?variant=orange-large': [26],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [26],
#   'https://web-scraping.dev/product/1?variant=orange-small': [26],
#   'https://web-scraping.dev/product/25': [26],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [26],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [26],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [26],
#   'https://web-scraping.dev/product/25?variant=orange-large': [26],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [26],
#   'https://web-scraping.dev/product/25?variant=orange-small': [26]},
#  'treat': {'https://web-scraping.dev/product/1': [27],
#   'https://web-scraping.dev/product/13': [27],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [27],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [27],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [27],
#   'https://web-scraping.dev/product/13?variant=orange-large': [27],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [27],
#   'https://web-scraping.dev/product/13?variant=orange-small': [27],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [27],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [27],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [27],
#   'https://web-scraping.dev/product/1?variant=orange-large': [27],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [27],
#   'https://web-scraping.dev/product/1?variant=orange-small': [27],
#   'https://web-scraping.dev/product/25': [27],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [27],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [27],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [27],
#   'https://web-scraping.dev/product/25?variant=orange-large': [27],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [27],
#   'https://web-scraping.dev/product/25?variant=orange-small': [27]},
#  'sure': {'https://web-scraping.dev/product/1': [31],
#   'https://web-scraping.dev/product/13': [31],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [31],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [31],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [31],
#   'https://web-scraping.dev/product/13?variant=orange-large': [31],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [31],
#   'https://web-scraping.dev/product/13?variant=orange-small': [31],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [31],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [31],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [31],
#   'https://web-scraping.dev/product/1?variant=orange-large': [31],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [31],
#   'https://web-scraping.dev/product/1?variant=orange-small': [31],
#   'https://web-scraping.dev/product/25': [31],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [31],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [31],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [31],
#   'https://web-scraping.dev/product/25?variant=orange-large': [31],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [31],
#   'https://web-scraping.dev/product/25?variant=orange-small': [31]},
#  'satisfy': {'https://web-scraping.dev/product/1': [32],
#   'https://web-scraping.dev/product/13': [32],
#   'https://web-scraping.dev/product/13?variant=cherry-large': [32],
#   'https://web-scraping.dev/product/13?variant=cherry-medium': [32],
#   'https://web-scraping.dev/product/13?variant=cherry-small': [32],
#   'https://web-scraping.dev/product/13?variant=orange-large': [32],
#   'https://web-scraping.dev/product/13?variant=orange-medium': [32],
#   'https://web-scraping.dev/product/13?variant=orange-small': [32],
#   'https://web-scraping.dev/product/1?variant=cherry-large': [32],
#   'https://web-scraping.dev/product/1?variant=cherry-medium': [32],
#   'https://web-scraping.dev/product/1?variant=cherry-small': [32],
#   'https://web-scraping.dev/product/1?variant=orange-large': [32],
#   'https://web-scraping.dev/product/1?variant=orange-medium': [32],
#   'https://web-scraping.dev/product/1?variant=orange-small': [32],
#   'https://web-scraping.dev/product/25': [32],
#   'https://web-scraping.dev/product/25?variant=cherry-large': [32],
#   'https://web-scraping.dev/product/25?variant=cherry-medium': [32],
#   'https://web-scraping.dev/product/25?variant=cherry-small': [32],
#   'https://web-scraping.dev/product/25?variant=orange-large': [32],
#   'https://web-scraping.dev/product/25?variant=orange-medium': [32],
#   'https://web-scraping.dev/product/25?variant=orange-small': [32]},
#  'elevate': {'https://web-scraping.dev/product/16': [0],
#   'https://web-scraping.dev/product/16?variant=one': [0],
#   'https://web-scraping.dev/product/16?variant=six-pack': [0],
#   'https://web-scraping.dev/product/28': [0],
#   'https://web-scraping.dev/product/28?variant=one': [0],
#   'https://web-scraping.dev/product/28?variant=six-pack': [0],
#   'https://web-scraping.dev/product/4': [0],
#   'https://web-scraping.dev/product/4?variant=one': [0],
#   'https://web-scraping.dev/product/4?variant=six-pack': [0]},
#  'game': {'https://web-scraping.dev/product/16': [1, 19],
#   'https://web-scraping.dev/product/16?variant=one': [1, 19],
#   'https://web-scraping.dev/product/16?variant=six-pack': [1, 19],
#   'https://web-scraping.dev/product/17': [15, 38, 41],
#   'https://web-scraping.dev/product/17?variant=one': [15, 38, 41],
#   'https://web-scraping.dev/product/17?variant=six-pack': [15, 38, 41],
#   'https://web-scraping.dev/product/28': [1, 19],
#   'https://web-scraping.dev/product/28?variant=one': [1, 19],
#   'https://web-scraping.dev/product/28?variant=six-pack': [1, 19],
#   'https://web-scraping.dev/product/4': [1, 19],
#   'https://web-scraping.dev/product/4?variant=one': [1, 19],
#   'https://web-scraping.dev/product/4?variant=six-pack': [1, 19],
#   'https://web-scraping.dev/product/5': [15, 38, 41],
#   'https://web-scraping.dev/product/5?variant=one': [15, 38, 41],
#   'https://web-scraping.dev/product/5?variant=six-pack': [15, 38, 41]},
#  'red': {'https://web-scraping.dev/product/16': [2, 10],
#   'https://web-scraping.dev/product/14': [3, 11],
#   'https://web-scraping.dev/product/14?variant=one': [3, 11],
#   'https://web-scraping.dev/product/14?variant=six-pack': [3, 11],
#   'https://web-scraping.dev/product/16?variant=one': [2, 10],
#   'https://web-scraping.dev/product/16?variant=six-pack': [2, 10],
#   'https://web-scraping.dev/product/2': [3, 11],
#   'https://web-scraping.dev/product/20': [27],
#   'https://web-scraping.dev/product/20?variant=beige-6': [27],
#   'https://web-scraping.dev/product/20?variant=beige-7': [27],
#   'https://web-scraping.dev/product/20?variant=beige-8': [27],
#   'https://web-scraping.dev/product/20?variant=blue-9': [27],
#   'https://web-scraping.dev/product/26': [3, 11],
#   'https://web-scraping.dev/product/26?variant=one': [3, 11],
#   'https://web-scraping.dev/product/26?variant=six-pack': [3, 11],
#   'https://web-scraping.dev/product/28': [2, 10],
#   'https://web-scraping.dev/product/28?variant=one': [2, 10],
#   'https://web-scraping.dev/product/28?variant=six-pack': [2, 10],
#   'https://web-scraping.dev/product/2?variant=one': [3, 11],
#   'https://web-scraping.dev/product/2?variant=six-pack': [3, 11],
#   'https://web-scraping.dev/product/4': [2, 10],
#   'https://web-scraping.dev/product/4?variant=one': [2, 10],
#   'https://web-scraping.dev/product/4?variant=six-pack': [2, 10],
#   'https://web-scraping.dev/product/8': [27],
#   'https://web-scraping.dev/product/8?variant=beige-6': [27],
#   'https://web-scraping.dev/product/8?variant=beige-7': [27],
#   'https://web-scraping.dev/product/8?variant=beige-8': [27],
#   'https://web-scraping.dev/product/8?variant=blue-9': [27]},
#  'potion': {'https://web-scraping.dev/product/16': [3, 11],
#   'https://web-scraping.dev/product/14': [4],
#   'https://web-scraping.dev/product/14?variant=one': [4],
#   'https://web-scraping.dev/product/14?variant=six-pack': [4],
#   'https://web-scraping.dev/product/15': [4, 17],
#   'https://web-scraping.dev/product/15?variant=one': [4, 17],
#   'https://web-scraping.dev/product/15?variant=six-pack': [4, 17],
#   'https://web-scraping.dev/product/16?variant=one': [3, 11],
#   'https://web-scraping.dev/product/16?variant=six-pack': [3, 11],
#   'https://web-scraping.dev/product/17': [5, 32],
#   'https://web-scraping.dev/product/17?variant=one': [5, 32],
#   'https://web-scraping.dev/product/17?variant=six-pack': [5, 32],
#   'https://web-scraping.dev/product/18': [4, 17],
#   'https://web-scraping.dev/product/18?variant=one': [4, 17],
#   'https://web-scraping.dev/product/18?variant=six-pack': [4, 17],
#   'https://web-scraping.dev/product/2': [4],
#   'https://web-scraping.dev/product/26': [4],
#   'https://web-scraping.dev/product/26?variant=one': [4],
#   'https://web-scraping.dev/product/26?variant=six-pack': [4],
#   'https://web-scraping.dev/product/27': [4, 17],
#   'https://web-scraping.dev/product/27?variant=one': [4, 17],
#   'https://web-scraping.dev/product/27?variant=six-pack': [4, 17],
#   'https://web-scraping.dev/product/28': [3, 11],
#   'https://web-scraping.dev/product/28?variant=one': [3, 11],
#   'https://web-scraping.dev/product/28?variant=six-pack': [3, 11],
#   'https://web-scraping.dev/product/2?variant=one': [4],
#   'https://web-scraping.dev/product/2?variant=six-pack': [4],
#   'https://web-scraping.dev/product/3': [4, 17],
#   'https://web-scraping.dev/product/3?variant=one': [4, 17],
#   'https://web-scraping.dev/product/3?variant=six-pack': [4, 17],
#   'https://web-scraping.dev/product/4': [3, 11],
#   'https://web-scraping.dev/product/4?variant=one': [3, 11],
#   'https://web-scraping.dev/product/4?variant=six-pack': [3, 11],
#   'https://web-scraping.dev/product/5': [5, 32],
#   'https://web-scraping.dev/product/5?variant=one': [5, 32],
#   'https://web-scraping.dev/product/5?variant=six-pack': [5, 32],
# ...
#   'https://web-scraping.dev/product/20?variant=beige-7': [16],
#   'https://web-scraping.dev/product/20?variant=beige-8': [16],
#   'https://web-scraping.dev/product/20?variant=blue-9': [16],
#   'https://web-scraping.dev/product/8': [16],
#   'https://web-scraping.dev/product/8?variant=beige-6': [16],
#   'https://web-scraping.dev/product/8?variant=beige-7': [16],
#   'https://web-scraping.dev/product/8?variant=beige-8': [16],
#   'https://web-scraping.dev/product/8?variant=blue-9': [16]},
#  'night': {'https://web-scraping.dev/product/20': [19],
#   'https://web-scraping.dev/product/20?variant=beige-6': [19],
#   'https://web-scraping.dev/product/20?variant=beige-7': [19],
#   'https://web-scraping.dev/product/20?variant=beige-8': [19],
#   'https://web-scraping.dev/product/20?variant=blue-9': [19],
#   'https://web-scraping.dev/product/8': [19],
#   'https://web-scraping.dev/product/8?variant=beige-6': [19],
#   'https://web-scraping.dev/product/8?variant=beige-7': [19],
#   'https://web-scraping.dev/product/8?variant=beige-8': [19],
#   'https://web-scraping.dev/product/8?variant=blue-9': [19]},
#  'buckle': {'https://web-scraping.dev/product/20': [20],
#   'https://web-scraping.dev/product/20?variant=beige-6': [20],
#   'https://web-scraping.dev/product/20?variant=beige-7': [20],
#   'https://web-scraping.dev/product/20?variant=beige-8': [20],
#   'https://web-scraping.dev/product/20?variant=blue-9': [20],
#   'https://web-scraping.dev/product/8': [20],
#   'https://web-scraping.dev/product/8?variant=beige-6': [20],
#   'https://web-scraping.dev/product/8?variant=beige-7': [20],
#   'https://web-scraping.dev/product/8?variant=beige-8': [20],
#   'https://web-scraping.dev/product/8?variant=blue-9': [20]},
#  'closure': {'https://web-scraping.dev/product/20': [21],
#   'https://web-scraping.dev/product/20?variant=beige-6': [21],
#   'https://web-scraping.dev/product/20?variant=beige-7': [21],
#   'https://web-scraping.dev/product/20?variant=beige-8': [21],
#   'https://web-scraping.dev/product/20?variant=blue-9': [21],
#   'https://web-scraping.dev/product/8': [21],
#   'https://web-scraping.dev/product/8?variant=beige-6': [21],
#   'https://web-scraping.dev/product/8?variant=beige-7': [21],
#   'https://web-scraping.dev/product/8?variant=beige-8': [21],
#   'https://web-scraping.dev/product/8?variant=blue-9': [21]},
#  'ensures': {'https://web-scraping.dev/product/20': [22],
#   'https://web-scraping.dev/product/20?variant=beige-6': [22],
#   'https://web-scraping.dev/product/20?variant=beige-7': [22],
#   'https://web-scraping.dev/product/20?variant=beige-8': [22],
#   'https://web-scraping.dev/product/20?variant=blue-9': [22],
#   'https://web-scraping.dev/product/8': [22],
#   'https://web-scraping.dev/product/8?variant=beige-6': [22],
#   'https://web-scraping.dev/product/8?variant=beige-7': [22],
#   'https://web-scraping.dev/product/8?variant=beige-8': [22],
#   'https://web-scraping.dev/product/8?variant=blue-9': [22]},
#  'secure': {'https://web-scraping.dev/product/20': [23],
#   'https://web-scraping.dev/product/20?variant=beige-6': [23],
#   'https://web-scraping.dev/product/20?variant=beige-7': [23],
#   'https://web-scraping.dev/product/20?variant=beige-8': [23],
#   'https://web-scraping.dev/product/20?variant=blue-9': [23],
#   'https://web-scraping.dev/product/8': [23],
#   'https://web-scraping.dev/product/8?variant=beige-6': [23],
#   'https://web-scraping.dev/product/8?variant=beige-7': [23],
#   'https://web-scraping.dev/product/8?variant=beige-8': [23],
#   'https://web-scraping.dev/product/8?variant=blue-9': [23]},
#  'fit': {'https://web-scraping.dev/product/20': [24],
#   'https://web-scraping.dev/product/20?variant=beige-6': [24],
#   'https://web-scraping.dev/product/20?variant=beige-7': [24],
#   'https://web-scraping.dev/product/20?variant=beige-8': [24],
#   'https://web-scraping.dev/product/20?variant=blue-9': [24],
#   'https://web-scraping.dev/product/8': [24],
#   'https://web-scraping.dev/product/8?variant=beige-6': [24],
#   'https://web-scraping.dev/product/8?variant=beige-7': [24],
#   'https://web-scraping.dev/product/8?variant=beige-8': [24],
#   'https://web-scraping.dev/product/8?variant=blue-9': [24]},
#  'nude': {'https://web-scraping.dev/product/20': [28],
#   'https://web-scraping.dev/product/20?variant=beige-6': [28],
#   'https://web-scraping.dev/product/20?variant=beige-7': [28],
#   'https://web-scraping.dev/product/20?variant=beige-8': [28],
#   'https://web-scraping.dev/product/20?variant=blue-9': [28],
#   'https://web-scraping.dev/product/8': [28],
#   'https://web-scraping.dev/product/8?variant=beige-6': [28],
#   'https://web-scraping.dev/product/8?variant=beige-7': [28],
#   'https://web-scraping.dev/product/8?variant=beige-8': [28],
#   'https://web-scraping.dev/product/8?variant=blue-9': [28]},
#  'silver': {'https://web-scraping.dev/product/20': [29],
#   'https://web-scraping.dev/product/20?variant=beige-6': [29],
#   'https://web-scraping.dev/product/20?variant=beige-7': [29],
#   'https://web-scraping.dev/product/20?variant=beige-8': [29],
#   'https://web-scraping.dev/product/20?variant=blue-9': [29],
#   'https://web-scraping.dev/product/8': [29],
#   'https://web-scraping.dev/product/8?variant=beige-6': [29],
#   'https://web-scraping.dev/product/8?variant=beige-7': [29],
#   'https://web-scraping.dev/product/8?variant=beige-8': [29],
#   'https://web-scraping.dev/product/8?variant=blue-9': [29]},
#  'runs': {'https://web-scraping.dev/product/21': [2],
#   'https://web-scraping.dev/product/21?variant=10': [2],
#   'https://web-scraping.dev/product/21?variant=11': [2],
#   'https://web-scraping.dev/product/21?variant=12': [2],
#   'https://web-scraping.dev/product/21?variant=9': [2],
#   'https://web-scraping.dev/product/9': [2],
#   'https://web-scraping.dev/product/9?variant=10': [2],
#   'https://web-scraping.dev/product/9?variant=11': [2],
#   'https://web-scraping.dev/product/9?variant=12': [2],
#   'https://web-scraping.dev/product/9?variant=9': [2]},
#  'men': {'https://web-scraping.dev/product/21': [3],
#   'https://web-scraping.dev/product/21?variant=10': [3],
#   'https://web-scraping.dev/product/21?variant=11': [3],
#   'https://web-scraping.dev/product/21?variant=12': [3],
#   'https://web-scraping.dev/product/21?variant=9': [3],
#   'https://web-scraping.dev/product/9': [3],
#   'https://web-scraping.dev/product/9?variant=10': [3],
#   'https://web-scraping.dev/product/9?variant=11': [3],
#   'https://web-scraping.dev/product/9?variant=12': [3],
#   'https://web-scraping.dev/product/9?variant=9': [3]},
#  'running': {'https://web-scraping.dev/product/21': [4],
#   'https://web-scraping.dev/product/21?variant=10': [4],
#   'https://web-scraping.dev/product/21?variant=11': [4],
#   'https://web-scraping.dev/product/21?variant=12': [4],
#   'https://web-scraping.dev/product/21?variant=9': [4],
#   'https://web-scraping.dev/product/9': [4],
#   'https://web-scraping.dev/product/9?variant=10': [4],
#   'https://web-scraping.dev/product/9?variant=11': [4],
#   'https://web-scraping.dev/product/9?variant=12': [4],
#   'https://web-scraping.dev/product/9?variant=9': [4]},
#  'featuring': {'https://web-scraping.dev/product/21': [6],
#   'https://web-scraping.dev/product/21?variant=10': [6],
#   'https://web-scraping.dev/product/21?variant=11': [6],
#   'https://web-scraping.dev/product/21?variant=12': [6],
#   'https://web-scraping.dev/product/21?variant=9': [6],
#   'https://web-scraping.dev/product/9': [6],
#   'https://web-scraping.dev/product/9?variant=10': [6],
#   'https://web-scraping.dev/product/9?variant=11': [6],
#   'https://web-scraping.dev/product/9?variant=12': [6],
#   'https://web-scraping.dev/product/9?variant=9': [6]},
#  'midsole': {'https://web-scraping.dev/product/21': [10],
#   'https://web-scraping.dev/product/21?variant=10': [10],
#   'https://web-scraping.dev/product/21?variant=11': [10],
#   'https://web-scraping.dev/product/21?variant=12': [10],
#   'https://web-scraping.dev/product/21?variant=9': [10],
#   'https://web-scraping.dev/product/9': [10],
#   'https://web-scraping.dev/product/9?variant=10': [10],
#   'https://web-scraping.dev/product/9?variant=11': [10],
#   'https://web-scraping.dev/product/9?variant=12': [10],
#   'https://web-scraping.dev/product/9?variant=9': [10]},
#  'provide': {'https://web-scraping.dev/product/21': [12],
#   'https://web-scraping.dev/product/21?variant=10': [12],
#   'https://web-scraping.dev/product/21?variant=11': [12],
#   'https://web-scraping.dev/product/21?variant=12': [12],
#   'https://web-scraping.dev/product/21?variant=9': [12],
#   'https://web-scraping.dev/product/9': [12],
#   'https://web-scraping.dev/product/9?variant=10': [12],
#   'https://web-scraping.dev/product/9?variant=11': [12],
#   'https://web-scraping.dev/product/9?variant=12': [12],
#   'https://web-scraping.dev/product/9?variant=9': [12]},
#  'ventilation': {'https://web-scraping.dev/product/21': [14],
#   'https://web-scraping.dev/product/21?variant=10': [14],
#   'https://web-scraping.dev/product/21?variant=11': [14],
#   'https://web-scraping.dev/product/21?variant=12': [14],
#   'https://web-scraping.dev/product/21?variant=9': [14],
#   'https://web-scraping.dev/product/9': [14],
#   'https://web-scraping.dev/product/9?variant=10': [14],
#   'https://web-scraping.dev/product/9?variant=11': [14],
#   'https://web-scraping.dev/product/9?variant=12': [14],
#   'https://web-scraping.dev/product/9?variant=9': [14]},
#  'shock': {'https://web-scraping.dev/product/21': [15],
#   'https://web-scraping.dev/product/21?variant=10': [15],
#   'https://web-scraping.dev/product/21?variant=11': [15],
#   'https://web-scraping.dev/product/21?variant=12': [15],
#   'https://web-scraping.dev/product/21?variant=9': [15],
#   'https://web-scraping.dev/product/9': [15],
#   'https://web-scraping.dev/product/9?variant=10': [15],
#   'https://web-scraping.dev/product/9?variant=11': [15],
#   'https://web-scraping.dev/product/9?variant=12': [15],
#   'https://web-scraping.dev/product/9?variant=9': [15]},
#  'absorption': {'https://web-scraping.dev/product/21': [16],
#   'https://web-scraping.dev/product/21?variant=10': [16],
#   'https://web-scraping.dev/product/21?variant=11': [16],
#   'https://web-scraping.dev/product/21?variant=12': [16],
#   'https://web-scraping.dev/product/21?variant=9': [16],
#   'https://web-scraping.dev/product/9': [16],
#   'https://web-scraping.dev/product/9?variant=10': [16],
#   'https://web-scraping.dev/product/9?variant=11': [16],
#   'https://web-scraping.dev/product/9?variant=12': [16],
#   'https://web-scraping.dev/product/9?variant=9': [16]},
#  'offers': {'https://web-scraping.dev/product/21': [19],
#   'https://web-scraping.dev/product/21?variant=10': [19],
#   'https://web-scraping.dev/product/21?variant=11': [19],
#   'https://web-scraping.dev/product/21?variant=12': [19],
#   'https://web-scraping.dev/product/21?variant=9': [19],
#   'https://web-scraping.dev/product/9': [19],
#   'https://web-scraping.dev/product/9?variant=10': [19],
#   'https://web-scraping.dev/product/9?variant=11': [19],
#   'https://web-scraping.dev/product/9?variant=12': [19],
#   'https://web-scraping.dev/product/9?variant=9': [19]},
#  'solid': {'https://web-scraping.dev/product/21': [20],
#   'https://web-scraping.dev/product/21?variant=10': [20],
#   'https://web-scraping.dev/product/21?variant=11': [20],
#   'https://web-scraping.dev/product/21?variant=12': [20],
#   'https://web-scraping.dev/product/21?variant=9': [20],
#   'https://web-scraping.dev/product/9': [20],
#   'https://web-scraping.dev/product/9?variant=10': [20],
#   'https://web-scraping.dev/product/9?variant=11': [20],
#   'https://web-scraping.dev/product/9?variant=12': [20],
#   'https://web-scraping.dev/product/9?variant=9': [20]},
#  'ensuring': {'https://web-scraping.dev/product/21': [22],
#   'https://web-scraping.dev/product/21?variant=10': [22],
#   'https://web-scraping.dev/product/21?variant=11': [22],
#   'https://web-scraping.dev/product/21?variant=12': [22],
#   'https://web-scraping.dev/product/21?variant=9': [22],
#   'https://web-scraping.dev/product/9': [22],
#   'https://web-scraping.dev/product/9?variant=10': [22],
#   'https://web-scraping.dev/product/9?variant=11': [22],
#   'https://web-scraping.dev/product/9?variant=12': [22],
#   'https://web-scraping.dev/product/9?variant=9': [22]},
#  'stability': {'https://web-scraping.dev/product/21': [23],
#   'https://web-scraping.dev/product/21?variant=10': [23],
#   'https://web-scraping.dev/product/21?variant=11': [23],
#   'https://web-scraping.dev/product/21?variant=12': [23],
#   'https://web-scraping.dev/product/21?variant=9': [23],
#   'https://web-scraping.dev/product/9': [23],
#   'https://web-scraping.dev/product/9?variant=10': [23],
#   'https://web-scraping.dev/product/9?variant=11': [23],
#   'https://web-scraping.dev/product/9?variant=12': [23],
#   'https://web-scraping.dev/product/9?variant=9': [23]},
#  'slippery': {'https://web-scraping.dev/product/21': [24],
#   'https://web-scraping.dev/product/21?variant=10': [24],
#   'https://web-scraping.dev/product/21?variant=11': [24],
#   'https://web-scraping.dev/product/21?variant=12': [24],
#   'https://web-scraping.dev/product/21?variant=9': [24],
#   'https://web-scraping.dev/product/9': [24],
#   'https://web-scraping.dev/product/9?variant=10': [24],
#   'https://web-scraping.dev/product/9?variant=11': [24],
#   'https://web-scraping.dev/product/9?variant=12': [24],
#   'https://web-scraping.dev/product/9?variant=9': [24]},
#  'surfaces': {'https://web-scraping.dev/product/21': [25],
#   'https://web-scraping.dev/product/21?variant=10': [25],
#   'https://web-scraping.dev/product/21?variant=11': [25],
#   'https://web-scraping.dev/product/21?variant=12': [25],
#   'https://web-scraping.dev/product/21?variant=9': [25],
#   'https://web-scraping.dev/product/9': [25],
#   'https://web-scraping.dev/product/9?variant=10': [25],
#   'https://web-scraping.dev/product/9?variant=11': [25],
#   'https://web-scraping.dev/product/9?variant=12': [25],
#   'https://web-scraping.dev/product/9?variant=9': [25]},
#  'options': {'https://web-scraping.dev/product/21': [29],
#   'https://web-scraping.dev/product/21?variant=10': [29],
#   'https://web-scraping.dev/product/21?variant=11': [29],
#   'https://web-scraping.dev/product/21?variant=12': [29],
#   'https://web-scraping.dev/product/21?variant=9': [29],
#   'https://web-scraping.dev/product/9': [29],
#   'https://web-scraping.dev/product/9?variant=10': [29],
#   'https://web-scraping.dev/product/9?variant=11': [29],
#   'https://web-scraping.dev/product/9?variant=12': [29],
#   'https://web-scraping.dev/product/9?variant=9': [29]},
#  'hit': {'https://web-scraping.dev/product/21': [30],
#   'https://web-scraping.dev/product/21?variant=10': [30],
#   'https://web-scraping.dev/product/21?variant=11': [30],
#   'https://web-scraping.dev/product/21?variant=12': [30],
#   'https://web-scraping.dev/product/21?variant=9': [30],
#   'https://web-scraping.dev/product/9': [30],
#   'https://web-scraping.dev/product/9?variant=10': [30],
#   'https://web-scraping.dev/product/9?variant=11': [30],
#   'https://web-scraping.dev/product/9?variant=12': [30],
#   'https://web-scraping.dev/product/9?variant=9': [30]},
#  'road': {'https://web-scraping.dev/product/21': [31],
#   'https://web-scraping.dev/product/21?variant=10': [31],
#   'https://web-scraping.dev/product/21?variant=11': [31],
#   'https://web-scraping.dev/product/21?variant=12': [31],
#   'https://web-scraping.dev/product/21?variant=9': [31],
#   'https://web-scraping.dev/product/9': [31],
#   'https://web-scraping.dev/product/9?variant=10': [31],
#   'https://web-scraping.dev/product/9?variant=11': [31],
#   'https://web-scraping.dev/product/9?variant=12': [31],
#   'https://web-scraping.dev/product/9?variant=9': [31]},
#  'treadmill': {'https://web-scraping.dev/product/21': [32],
#   'https://web-scraping.dev/product/21?variant=10': [32],
#   'https://web-scraping.dev/product/21?variant=11': [32],
#   'https://web-scraping.dev/product/21?variant=12': [32],
#   'https://web-scraping.dev/product/21?variant=9': [32],
#   'https://web-scraping.dev/product/9': [32],
#   'https://web-scraping.dev/product/9?variant=10': [32],
#   'https://web-scraping.dev/product/9?variant=11': [32],
#   'https://web-scraping.dev/product/9?variant=12': [32],
#   'https://web-scraping.dev/product/9?variant=9': [32]}}

# %%
# Création des index pour le reviews
def create_reviews_index(data):
    index = {}

    for url, reviews in zip(data['url'], data['product_reviews']):
        total_reviews = len(reviews)
        mean_mark = sum(review['rating'] for review in reviews) / total_reviews if total_reviews > 0 else 0
        last_rating = reviews[-1]['rating'] if total_reviews > 0 else None
        index[url] = {
            'total_reviews': total_reviews,
            'mean_mark': mean_mark,
            'last_rating': last_rating
        }
    
    return index

# %%
index_reviews = create_reviews_index(data)
index_reviews
# Out:
# {'https://web-scraping.dev/products': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/product/1': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/16': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/10': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/10?variant=blue-5': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/10?variant=blue-6': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/10?variant=red-5': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/10?variant=red-6': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/11': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/11?variant=black40': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/11?variant=black41': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/11?variant=black42': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/11?variant=white40': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/11?variant=white41': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/11?variant=white42': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/12': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/12?variant=darkgrey-medium': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/12?variant=darkgrey-small': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/12?variant=grey-medium': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/12?variant=grey-small': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/12?variant=pink-medium': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/12?variant=pink-small': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/12?variant=sand-medium': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/12?variant=sand-small': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/13': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/13?variant=cherry-large': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/13?variant=cherry-medium': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/13?variant=cherry-small': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/13?variant=orange-large': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/13?variant=orange-medium': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/13?variant=orange-small': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/14': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/14?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/14?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/15': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/15?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/15?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/16?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/16?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/17': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/17?variant=one': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/17?variant=six-pack': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/18': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/18?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/18?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/19': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/19?variant=6': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/19?variant=7': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/19?variant=8': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/19?variant=9': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/1?variant=cherry-large': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/1?variant=cherry-medium': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/1?variant=cherry-small': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/1?variant=orange-large': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/1?variant=orange-medium': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/1?variant=orange-small': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/2': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/20': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/20?variant=beige-6': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/20?variant=beige-7': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/20?variant=beige-8': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/20?variant=blue-9': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/21': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/21?variant=10': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/21?variant=11': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/21?variant=12': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/21?variant=9': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/22': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/22?variant=blue-5': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/22?variant=blue-6': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/22?variant=red-5': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/22?variant=red-6': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/23': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/23?variant=black40': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/23?variant=black41': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/23?variant=black42': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/23?variant=white40': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/23?variant=white41': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/23?variant=white42': {'total_reviews': 5,
#   'mean_mark': 4.4,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/24': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/24?variant=darkgrey-medium': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/24?variant=darkgrey-small': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/24?variant=grey-medium': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/24?variant=grey-small': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/24?variant=pink-medium': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/24?variant=pink-small': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/24?variant=sand-medium': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/24?variant=sand-small': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/25': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/25?variant=cherry-large': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/25?variant=cherry-medium': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/25?variant=cherry-small': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/25?variant=orange-large': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/25?variant=orange-medium': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/25?variant=orange-small': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/26': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/26?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/26?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/27': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/27?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/27?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/28': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/28?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/28?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/2?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/2?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/3': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/3?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/3?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/4': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/4?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/4?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/5': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/5?variant=one': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/5?variant=six-pack': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/6': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/6?variant=one': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/6?variant=six-pack': {'total_reviews': 4,
#   'mean_mark': 4.75,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/7': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/7?variant=6': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/7?variant=7': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/7?variant=8': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/7?variant=9': {'total_reviews': 5,
#   'mean_mark': 4.6,
#   'last_rating': 5},
#  'https://web-scraping.dev/product/8': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/8?variant=beige-6': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/8?variant=beige-7': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/8?variant=beige-8': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/8?variant=blue-9': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/9': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/9?variant=10': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/9?variant=11': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/9?variant=12': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/product/9?variant=9': {'total_reviews': 5,
#   'mean_mark': 4.2,
#   'last_rating': 4},
#  'https://web-scraping.dev/products?category=apparel': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=apparel&page=1': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=apparel&page=2': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=apparel&page=3': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=apparel&page=4': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=apparel&page=5': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=consumables': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=consumables&page=1': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=consumables&page=2': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=consumables&page=3': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=consumables&page=4': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=consumables&page=5': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=household': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=household&page=1': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=household&page=2': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=household&page=3': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=household&page=4': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?category=household&page=5': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?page=1': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?page=2': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?page=3': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?page=4': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None},
#  'https://web-scraping.dev/products?page=5': {'total_reviews': 0,
#   'mean_mark': 0,
#   'last_rating': None}}

# %%
# Création des index inversés pour les features comme marque et origine.
def create_features_index(data, feature):
    index = {}

    for url, features in zip(data['url'], data['product_features']):
        feature_value = features.get(feature)
        feature_value = remove_stopwords_punctuation(feature_value) if feature_value else []
        for token in feature_value:
            if token not in index:
                index[token] = set()
            index[token].add(url)

    return index

# %%
# index_origin = create_features_index(data, 'made in')
index_brand = create_features_index(data, 'brand')
#index_material = create_features_index(data, 'material')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[103], line 2
#       1 # index_origin = create_features_index(data, 'made in')
# ----> 2 index_brand = create_features_index(data, 'brand')
#       3 #index_material = create_features_index(data, 'material')
#
# Cell In[102], line 7, in create_features_index(data, feature)
#       5 for url, features in zip(data['url'], data['product_features']):
#       6     feature_value = features.get(feature)
# ----> 7     feature_value = remove_stopwords_punctuation(feature_value) if feature_value else []
#       8     for token in feature_value:
#       9         if token not in index:
#
# Cell In[50], line 3, in remove_stopwords_punctuation(text)
#       2 def remove_stopwords_punctuation(text):
# ----> 3     nlp = spacy.load("en_core_web_sm")
#       4     doc = nlp(text)
#       5     tokens = [token.text.lower() for token in doc if not token.is_stop and not token.is_punct]
#
# File ~/.local/lib/python3.10/site-packages/spacy/__init__.py:52, in load(name, vocab, disable, enable, exclude, config)
#      28 def load(
#      29     name: Union[str, Path],
#      30     *,
#    (...)
#      35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)
#      50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#      55         disable=disable,
#      56         enable=enable,
#      57         exclude=exclude,
#      58         config=config,
#      59     )
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:524, in load_model(name, vocab, disable, enable, exclude, config)
#     522     return get_lang_class(name.replace("blank:", ""))()
#     523 if is_package(name):  # installed as package
# --> 524     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     525 if Path(name).exists():  # path to model data directory
#     526     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:560, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     543 """Load a model from an installed package.
#     544
#     545 name (str): The package name.
#    (...)
#     557 RETURNS (Language): The loaded nlp object.
#     558 """
#     559 cls = importlib.import_module(name)
# --> 560 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~/.local/lib/python3.10/site-packages/en_core_web_sm/__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:741, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     739 if not model_path.exists():
#     740     raise IOError(Errors.E052.format(path=data_path))
# --> 741 return load_model_from_path(
#     742     data_path,
#     743     vocab=vocab,
#     744     meta=meta,
#     745     disable=disable,
#     746     enable=enable,
#     747     exclude=exclude,
#     748     config=config,
#     749 )
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:606, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     597 config = load_config(config_path, overrides=overrides)
#     598 nlp = load_model_from_config(
#     599     config,
#     600     vocab=vocab,
#    (...)
#     604     meta=meta,
#     605 )
# --> 606 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File ~/.local/lib/python3.10/site-packages/spacy/language.py:2245, in Language.from_disk(self, path, exclude, overrides)
#    2242 if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#    2243     # Convert to list here in case exclude is (default) tuple
#    2244     exclude = list(exclude) + ["vocab"]
# -> 2245 util.from_disk(path, deserializers, exclude)  # type: ignore[arg-type]
#    2246 self._path = path  # type: ignore[assignment]
#    2247 self._link_components()
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:1448, in from_disk(path, readers, exclude)
#    1445 for key, reader in readers.items():
#    1446     # Split to support file names like meta.json
#    1447     if key.split(".")[0] not in exclude:
# -> 1448         reader(path / key)
#    1449 return path
#
# File ~/.local/lib/python3.10/site-packages/spacy/language.py:2239, in Language.from_disk.<locals>.<lambda>(p, proc)
#    2237     if not hasattr(proc, "from_disk"):
#    2238         continue
# -> 2239     deserializers[name] = lambda p, proc=proc: proc.from_disk(  # type: ignore[misc]
#    2240         p, exclude=["vocab"]
#    2241     )
#    2242 if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#    2243     # Convert to list here in case exclude is (default) tuple
#    2244     exclude = list(exclude) + ["vocab"]
#
# File ~/.local/lib/python3.10/site-packages/spacy/pipeline/trainable_pipe.pyx:343, in spacy.pipeline.trainable_pipe.TrainablePipe.from_disk()
#
# File ~/.local/lib/python3.10/site-packages/spacy/util.py:1448, in from_disk(path, readers, exclude)
#    1445 for key, reader in readers.items():
#    1446     # Split to support file names like meta.json
#    1447     if key.split(".")[0] not in exclude:
# -> 1448         reader(path / key)
#    1449 return path
#
# File ~/.local/lib/python3.10/site-packages/spacy/pipeline/trainable_pipe.pyx:333, in spacy.pipeline.trainable_pipe.TrainablePipe.from_disk.load_model()
#
# File ~/.local/lib/python3.10/site-packages/spacy/pipeline/trainable_pipe.pyx:334, in spacy.pipeline.trainable_pipe.TrainablePipe.from_disk.load_model()
#
# File ~/.local/lib/python3.10/site-packages/thinc/model.py:638, in Model.from_bytes(self, bytes_data)
#     636 msg = srsly.msgpack_loads(bytes_data)
#     637 msg = convert_recursive(is_xp_array, self.ops.asarray, msg)
# --> 638 return self.from_dict(msg)
#
# File ~/.local/lib/python3.10/site-packages/thinc/model.py:669, in Model.from_dict(self, msg)
#     667 for attr, value in msg["attrs"][i].items():
#     668     default_value = node.attrs.get(attr)
# --> 669     loaded_value = deserialize_attr(default_value, value, attr, node)
#     670     node.attrs[attr] = loaded_value
#     671 for param_name, value in msg["params"][i].items():
#
# File /usr/lib/python3.10/functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/.local/lib/python3.10/site-packages/thinc/model.py:849, in deserialize_attr(_, value, name, model)
#     843 @functools.singledispatch
#     844 def deserialize_attr(_: Any, value: Any, name: str, model: Model) -> Any:
#     845     """Deserialize an attribute value (defaults to msgpack). You can register
#     846     custom deserializers using the @deserialize_attr.register decorator with the
#     847     type to deserialize, e.g.: @deserialize_attr.register(MyCustomObject).
#     848     """
# --> 849     return srsly.msgpack_loads(value)
#
# File ~/.local/lib/python3.10/site-packages/srsly/_msgpack_api.py:27, in msgpack_loads(data, use_list)
#      25 # msgpack-python docs suggest disabling gc before unpacking large messages
#      26 gc.disable()
# ---> 27 msg = msgpack.loads(data, raw=False, use_list=use_list)
#      28 gc.enable()
#      29 return msg
#
# File ~/.local/lib/python3.10/site-packages/srsly/msgpack/__init__.py:82, in unpackb(packed, **kwargs)
#      80 if "object_pairs_hook" not in kwargs:
#      81     object_hook = kwargs.get("object_hook")
# ---> 82     for decoder in msgpack_decoders.get_all().values():
#      83         object_hook = functools.partial(decoder, chain=object_hook)
#      84     kwargs["object_hook"] = object_hook
#
# File ~/.local/lib/python3.10/site-packages/catalogue/__init__.py:110, in Registry.get_all(self)
#     108 result = {}
#     109 if self.entry_points:
# --> 110     result.update(self.get_entry_points())
#     111 for keys, value in REGISTRY.copy().items():
#     112     if len(self.namespace) == len(keys) - 1 and all(
#     113         self.namespace[i] == keys[i] for i in range(len(self.namespace))
#     114     ):
#
# File ~/.local/lib/python3.10/site-packages/catalogue/__init__.py:124, in Registry.get_entry_points(self)
#     119 """Get registered entry points from other packages for this namespace.
#     120
#     121 RETURNS (Dict[str, Any]): Entry points, keyed by name.
#     122 """
#     123 result = {}
# --> 124 for entry_point in self._get_entry_points():
#     125     result[entry_point.name] = entry_point.load()
#     126 return result
#
# File ~/.local/lib/python3.10/site-packages/catalogue/__init__.py:143, in Registry._get_entry_points(self)
#     141 def _get_entry_points(self) -> List[importlib_metadata.EntryPoint]:
#     142     if hasattr(AVAILABLE_ENTRY_POINTS, "select"):
# --> 143         return AVAILABLE_ENTRY_POINTS.select(group=self.entry_point_namespace)
#     144     else:  # dict
#     145         return AVAILABLE_ENTRY_POINTS.get(self.entry_point_namespace, [])
#
# File /usr/lib/python3.10/importlib/metadata/__init__.py:487, in SelectableGroups.select(self, **params)
#     485 if not params:
#     486     return self
# --> 487 return self._all.select(**params)
#
# File /usr/lib/python3.10/importlib/metadata/__init__.py:359, in EntryPoints.select(self, **params)
#     354 def select(self, **params):
#     355     """
#     356     Select entry points from self that match the
#     357     given parameters (typically group and/or name).
#     358     """
# --> 359     return EntryPoints(ep for ep in self if ep.matches(**params))
#
# File /usr/lib/python3.10/importlib/metadata/__init__.py:359, in <genexpr>(.0)
#     354 def select(self, **params):
#     355     """
#     356     Select entry points from self that match the
#     357     given parameters (typically group and/or name).
#     358     """
# --> 359     return EntryPoints(ep for ep in self if ep.matches(**params))
#
# KeyboardInterrupt:
